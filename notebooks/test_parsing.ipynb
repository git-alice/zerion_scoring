# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from sys import path
path.append('../')

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import datetime

from core.request import FactoryClient

# %%
address_top100 = pd.read_csv('../data/address__top100_by_trades.csv', header=None)
address_small = pd.read_csv('../data/address__2-3_trades.csv', header=None)

# %%
address_top100[0] = address_top100[0].transform(lambda x: x.replace('\\', '0'))
address_small[0] = address_small[0].transform(lambda x: x.replace('\\', '0'))

# %%
np.save('../data/address_top100', address_top100.values)
np.save('../data/address__2_3_trades', address_small.values)

# %%
test_address = '0x7e5ce10826ee167de897d262fcc9976f609ecd2b'

f = FactoryClient(setting_path='../settings.yaml')
result2 = f.sync_request(
    namespace='/address',
    payload={
        'address': test_address
    },
    scope='transactions'
)
# Out:
# Connected to /address namespace!
# Address portfolio is received

# %%
result2
# Out:
# [{'id': '827f8b05-fb664ffdaac7101f-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1623409428,
#   'block_number': 12612869,
#   'status': 'confirmed',
#   'hash': '0xfb664ffdaac7101f2b751eb5e3c45e60a4dc52431d9f79cecb85c4c2b7781ff2',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x51020400c2aa3ed9856435716c50b6ef2f38e084',
#   'contract': None,
#   'nonce': 660,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 500000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x51020400c2aa3ed9856435716c50b6ef2f38e084',
#     'price': 2485.25}],
#   'fee': {'value': 1050000000000000, 'price': 2485.25},
#   'meta': {}},
#  {'id': 'b86be81e-f5ca1d47c7cedd8c-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1623405033,
#   'block_number': 12612563,
#   'status': 'confirmed',
#   'hash': '0xf5ca1d47c7cedd8cdd6dd7ca221924c6230576cfb9a689d640e9cdc736a57db0',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x401f6c983ea34274ec46f84d70b31c151321188b',
#   'contract': None,
#   'nonce': 659,
#   'changes': [{'asset': {'asset_code': '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0',
#      'name': 'Polygon (Matic)',
#      'symbol': 'MATIC',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0new.png',
#      'price': {'value': 1.27371336665177,
#       'relative_change_24h': -5.221904482818629,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 181125496290420261156,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x401f6c983ea34274ec46f84d70b31c151321188b',
#     'price': 1.3633717075}],
#   'fee': {'value': 1669524000000000, 'price': 2472.25},
#   'meta': {}},
#  {'id': '1c2a973a-41411bca53285eab-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1623404930,
#   'block_number': 12612558,
#   'status': 'confirmed',
#   'hash': '0x41411bca53285eab62a5a03fdc2d7d180586dd3658fca1a75611faea3fd94f0b',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0',
#   'contract': None,
#   'nonce': 658,
#   'changes': [],
#   'fee': {'value': 585168000000000, 'price': 2472.44},
#   'meta': {'action': 'Approval',
#    'amount': 1.157920892373162e+77,
#    'spender': '0x401f6c983ea34274ec46f84d70b31c151321188b',
#    'asset': {'asset_code': '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0',
#     'name': 'Polygon (Matic)',
#     'symbol': 'MATIC',
#     'decimals': 18,
#     'type': None,
#     'icon_url': 'https://token-icons.s3.amazonaws.com/0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0new.png',
#     'price': {'value': 1.27371336665177,
#      'relative_change_24h': -5.221904482818629,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': True}}},
#  {'id': 'fe70dbcf-669a5ea0e08a3806-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1623404837,
#   'block_number': 12612549,
#   'status': 'confirmed',
#   'hash': '0x669a5ea0e08a380688c2b1f455c3d9533de5a74277764921d96b2ae51edc0f29',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x1bd435f3c054b6e901b7b108a0ab7617c808677b',
#   'contract': None,
#   'nonce': 657,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 100000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x1bd435f3c054b6e901b7b108a0ab7617c808677b',
#     'price': 2474.66},
#    {'asset': {'asset_code': '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0',
#      'name': 'Polygon (Matic)',
#      'symbol': 'MATIC',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0new.png',
#      'price': {'value': 1.27371336665177,
#       'relative_change_24h': -5.221904482818629,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 181125496290420261156,
#     'direction': 'in',
#     'address_from': '0x819f3450da6f110ba6ea52195b3beafa246062de',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1.3647007502}],
#   'fee': {'value': 1751960182579260, 'price': 2474.66},
#   'meta': {}},
#  {'id': 'e7b398b4-90a0962c0f126b16-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1623081460,
#   'block_number': 12588331,
#   'status': 'confirmed',
#   'hash': '0x90a0962c0f126b167822684c46592075734e6dc1e78cdcaf101a932a8c0d4974',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x4976fb03c32e5b8cfe2b6ccb31c09ba78ebaba41',
#   'contract': None,
#   'nonce': 656,
#   'changes': [],
#   'fee': {'value': 1001920000000000, 'price': 2785.92},
#   'meta': {}},
#  {'id': '24c0fbb1-3af2f48b73026180-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1623075191,
#   'block_number': 12587858,
#   'status': 'confirmed',
#   'hash': '0x3af2f48b730261807df43b9928c3f86da1495be4db31df3cb0a3fdcbe5d9f455',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x00000000000c2e074ec69a0dfb2997ba6c7d2e1e',
#   'contract': None,
#   'nonce': 655,
#   'changes': [],
#   'fee': {'value': 1190080000000000, 'price': 2788.27},
#   'meta': {}},
#  {'id': 'c3d4dd1e-bdbeaf29b4465fb2-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1623075186,
#   'block_number': 12587857,
#   'status': 'confirmed',
#   'hash': '0xbdbeaf29b4465fb243c936de13f7dc62f6e1213ad265e5b49bc743f724837f02',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x00000000000c2e074ec69a0dfb2997ba6c7d2e1e',
#   'contract': None,
#   'nonce': 654,
#   'changes': [],
#   'fee': {'value': 499440000000000, 'price': 2788.27},
#   'meta': {}},
#  {'id': '693b6ca8-f47f9774bff1f269-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1622627633,
#   'block_number': 12554360,
#   'status': 'confirmed',
#   'hash': '0xf47f9774bff1f2694048f616fc50943c8617edf10f8b1e7fdfca3afa960e1c3b',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xfaff15c6cdaca61a4f87d329689293e07c98f578',
#   'contract': None,
#   'nonce': 653,
#   'changes': [],
#   'fee': {'value': 1683343000000000, 'price': 2697.91},
#   'meta': {}},
#  {'id': '82ef8b09-9ddff2f4c51808d6-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1622627442,
#   'block_number': 12554344,
#   'status': 'confirmed',
#   'hash': '0x9ddff2f4c51808d6a1da4d754b28406f5e98603a21bf06f89f26996f43e41c9d',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'contract': None,
#   'nonce': 652,
#   'changes': [{'asset': {'asset_code': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#      'name': 'Wrapped Ether',
#      'symbol': 'WETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1528341939061907966,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#     'price': 2699.67},
#    {'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1528341939061907966,
#     'direction': 'in',
#     'address_from': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 2699.67}],
#   'fee': {'value': 355232000000000, 'price': 2699.67},
#   'meta': {}},
#  {'id': '831b42be-8ef1b4a80ed452de-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1622627403,
#   'block_number': 12554339,
#   'status': 'confirmed',
#   'hash': '0x8ef1b4a80ed452dea16264a23acddcae808931eb15aac98300cdde397a853b7e',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'contract': None,
#   'nonce': 651,
#   'changes': [],
#   'fee': {'value': 963060000000000, 'price': 2699.71},
#   'meta': {'action': 'Approval',
#    'amount': 7.922816251426e+28,
#    'spender': '0x0000000000000000000000000000000000000000',
#    'asset': {'asset_code': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#     'name': 'Wrapped Ether',
#     'symbol': 'WETH',
#     'decimals': 18,
#     'type': None,
#     'icon_url': 'https://s3.amazonaws.com/token-icons/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png',
#     'price': {'value': 2421.77,
#      'relative_change_24h': -0.866578794403472,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': True}}},
#  {'id': '5eef1734-4434109bab66c81b-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1622039428,
#   'block_number': 12510486,
#   'status': 'confirmed',
#   'hash': '0x4434109bab66c81bde5588b102be850f1a6ceee9a3ad14f5a91ff37b84be1ad3',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xde3e5a990bce7fc60a6f017e7c4a95fc4939299e',
#   'contract': None,
#   'nonce': 650,
#   'changes': [{'asset': {'asset_code': '0xde30da39c46104798bb5aa3fe8b9e0e1f348163f',
#      'name': 'Gitcoin',
#      'symbol': 'GTC',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xde30da39c46104798bb5aa3fe8b9e0e1f348163f.png',
#      'price': {'value': 11.64270917865283,
#       'relative_change_24h': -22.807895097337337,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1214619500000000081920,
#     'direction': 'in',
#     'address_from': '0xde3e5a990bce7fc60a6f017e7c4a95fc4939299e',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 6.846156725}],
#   'fee': {'value': 5367420000000000, 'price': 2763.5},
#   'meta': {}},
#  {'id': 'fbadf8d3-cc3b3f1e25b971cb-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1621114628,
#   'block_number': 12441481,
#   'status': 'confirmed',
#   'hash': '0xcc3b3f1e25b971cb05d1908e9d38a053d05d82fde07c6d3b08a3243cacfca43f',
#   'direction': None,
#   'address_from': '0x57db468255865f652bd8735b477a34ffb5b53f4d',
#   'address_to': '0xa5025faba6e70b84f74e9b1113e5f7f4e7f4859f',
#   'contract': None,
#   'nonce': 7,
#   'changes': [{'asset': {'asset_code': '0xa0335820dc549dbfae5b8d691331cadfca7026e0',
#      'name': 'Shiba v2 Limited',
#      'symbol': 'shiba2',
#      'decimals': 18,
#      'type': None,
#      'icon_url': None,
#      'price': None,
#      'is_displayable': True,
#      'is_verified': False},
#     'value': 100856703610000000000,
#     'direction': 'in',
#     'address_from': '0xa5025faba6e70b84f74e9b1113e5f7f4e7f4859f',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': None}],
#   'fee': None,
#   'meta': {}},
#  {'id': 'f275a634-df07d509ecce78bb-7e5ce108',
#   'type': 'claim',
#   'protocol': 'curve',
#   'mined_at': 1620998825,
#   'block_number': 12432774,
#   'status': 'confirmed',
#   'hash': '0xdf07d509ecce78bbe85d4ec6fe52b6428030e951d83130374373554ebd0f8a61',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#   'contract': None,
#   'nonce': 649,
#   'changes': [{'asset': {'asset_code': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'name': 'Curve DAO Token',
#      'symbol': 'CRV',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'price': {'value': 2.2299031781976884,
#       'relative_change_24h': 3.0080892938767922,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 408771182601537655542,
#     'direction': 'in',
#     'address_from': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 3.64325643}],
#   'fee': {'value': 6343150000000000, 'price': 3978.44},
#   'meta': {'action': 'Claim Rewards', 'application': 'Curve'}},
#  {'id': '7bac7a66-36ae65b94c969949-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1620922438,
#   'block_number': 12427032,
#   'status': 'confirmed',
#   'hash': '0x36ae65b94c9699498b37e89f3b51d95a4a401855fd462db57aea12e1ee264db5',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xaf7eaf66b5f1fa23158784fb4c17dba90727afad',
#   'contract': None,
#   'nonce': 648,
#   'changes': [],
#   'fee': {'value': 12166084000000000, 'price': 3826.71},
#   'meta': {}},
#  {'id': '0e0397a1-b0f93dca3b005374-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1620812923,
#   'block_number': 12418910,
#   'status': 'confirmed',
#   'hash': '0xb0f93dca3b00537453141f6948dbd87a37a05474fb210d247dfb67c7eb149674',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xa0c68c638235ee32657e8f720a23cec1bfc77c77',
#   'contract': None,
#   'nonce': 647,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1000000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0xa0c68c638235ee32657e8f720a23cec1bfc77c77',
#     'price': 4310.32}],
#   'fee': {'value': 10120667000000000, 'price': 4310.32},
#   'meta': {}},
#  {'id': 'aec9d6f4-44c59bf93a259efc-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1620737097,
#   'block_number': 12413208,
#   'status': 'confirmed',
#   'hash': '0x44c59bf93a259efca7b7e19bf74a72ab4379e3649214a32fb489e112ec603654',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x295e5019e065c71ab3b0353984fbdfe4fe739291',
#   'contract': None,
#   'nonce': 646,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1000000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x295e5019e065c71ab3b0353984fbdfe4fe739291',
#     'price': 3944.98}],
#   'fee': {'value': 6321000000000000, 'price': 3944.98},
#   'meta': {}},
#  {'id': 'a73d5712-dc924feb77472133-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1620593170,
#   'block_number': 12402374,
#   'status': 'confirmed',
#   'hash': '0xdc924feb77472133d4dceea73776282bca3264bc5902204b9a107be6480c530a',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x9d1f1847582261be41f5a54e8b60cad21400c74f',
#   'contract': None,
#   'nonce': 645,
#   'changes': [{'asset': {'asset_code': '0x2d94aa3e47d9d5024503ca8491fce9a2fb4da198',
#      'name': 'Bankless Token',
#      'symbol': 'BANK',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x2d94aa3e47d9d5024503ca8491fce9a2fb4da198.png',
#      'price': {'value': 0.025041101799999996,
#       'relative_change_24h': -2.28412056569417,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 17279207768580000055296,
#     'direction': 'in',
#     'address_from': '0x9d1f1847582261be41f5a54e8b60cad21400c74f',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 0.0821745099}],
#   'fee': {'value': 9330871068750000, 'price': 3918.67},
#   'meta': {}},
#  {'id': 'fa5585ae-1091e7bec938b71b-7e5ce108',
#   'type': 'trade',
#   'protocol': 'set',
#   'mined_at': 1619100517,
#   'block_number': 12290480,
#   'status': 'confirmed',
#   'hash': '0x1091e7bec938b71b01398e06ba5573a2f1098e410074d7d02576f9b082c035ea',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xda6786379ff88729264d31d472fa917f5e561443',
#   'contract': None,
#   'nonce': 644,
#   'changes': [{'asset': {'asset_code': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#      'name': 'Wrapped Ether',
#      'symbol': 'WETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 240831003560025816,
#     'direction': 'in',
#     'address_from': '0x5b67871c3a857de81a1ca0f9f7945e5670d986dc',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 2556.07},
#    {'asset': {'asset_code': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#      'name': 'Wrapped BTC',
#      'symbol': 'WBTC',
#      'decimals': 8,
#      'type': 'bitcoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599.png',
#      'price': {'value': 35867.12570038,
#       'relative_change_24h': -3.6899232061536558,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 167181,
#     'direction': 'in',
#     'address_from': '0x5b67871c3a857de81a1ca0f9f7945e5670d986dc',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 54969.31033407},
#    {'asset': {'asset_code': '0xa6c040045d962e4b8efa00954c7d23ccd0a2b8ad',
#      'name': 'BitEth2575RebalancingSetToken',
#      'symbol': 'BTCETH2575',
#      'decimals': 18,
#      'type': 'tokenset',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa6c040045d962e4b8efa00954c7d23ccd0a2b8ad.png',
#      'price': {'value': 1311.1697422798668,
#       'relative_change_24h': -1.136765631623915,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': False},
#     'value': 490554896773000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x0000000000000000000000000000000000000000',
#     'price': None}],
#   'fee': {'value': 65203079409930168, 'price': 2556.07},
#   'meta': {'application': 'Set'}},
#  {'id': '7ac5cff3-7510e58228782a5e-7e5ce108',
#   'type': 'trade',
#   'protocol': 'set',
#   'mined_at': 1619100285,
#   'block_number': 12290463,
#   'status': 'confirmed',
#   'hash': '0x7510e58228782a5e58dcf5cb3d3465ef52e5429d2b86daaecfdf922b66d00ea6',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xda6786379ff88729264d31d472fa917f5e561443',
#   'contract': None,
#   'nonce': 643,
#   'changes': [{'asset': {'asset_code': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#      'name': 'Wrapped Ether',
#      'symbol': 'WETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1281546705895948288,
#     'direction': 'in',
#     'address_from': '0x5b67871c3a857de81a1ca0f9f7945e5670d986dc',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 2547.02},
#    {'asset': {'asset_code': '0x316b13b951efe25aad1cb565385b23869a7d4c48',
#      'name': 'ETH 26 EMA Crossover Yield',
#      'symbol': 'ETHEMAAPY',
#      'decimals': 18,
#      'type': 'tokenset',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x316b13b951efe25aad1cb565385b23869a7d4c48.png',
#      'price': {'value': 1693.8067182590362,
#       'relative_change_24h': -0.8665787944034609,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': False},
#     'value': 1832329115618000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x0000000000000000000000000000000000000000',
#     'price': None}],
#   'fee': {'value': 46281338000000000, 'price': 2547.02},
#   'meta': {'application': 'Set'}},
#  {'id': 'c5690f7e-75737c54f802ed18-7e5ce108',
#   'type': 'trade',
#   'protocol': 'defi_sdk',
#   'mined_at': 1619098809,
#   'block_number': 12290332,
#   'status': 'confirmed',
#   'hash': '0x75737c54f802ed182e42243085826e2d9c2ee4cdbced49083ab5abd772761ccf',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xb2be281e8b11b47fec825973fc8bb95332022a54',
#   'contract': None,
#   'nonce': 642,
#   'changes': [{'asset': {'asset_code': '0x9ea463ec4ce9e9e5bc9cfd0187c4ac3a70dd951d',
#      'name': 'ETH 20 SMA Crossover Set',
#      'symbol': 'ETH20SMACO',
#      'decimals': 18,
#      'type': 'tokenset',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x9ea463ec4ce9e9e5bc9cfd0187c4ac3a70dd951d.png',
#      'price': {'value': 2104.69504514204,
#       'relative_change_24h': -0.8665787944034831,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': False},
#     'value': 5000000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0xd291328a6c202c5b18dcb24f279f69de1e065f70',
#     'price': None},
#    {'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 4345365260000000000,
#     'direction': 'in',
#     'address_from': '0xd291328a6c202c5b18dcb24f279f69de1e065f70',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 2587.14}],
#   'fee': {'value': 52480971000000000, 'price': 2587.14},
#   'meta': {'application': 'DeFi SDK'}},
#  {'id': '1d9803a5-218b41b9c7880a1b-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1619098689,
#   'block_number': 12290323,
#   'status': 'confirmed',
#   'hash': '0x218b41b9c7880a1b27b10e4f2d4ad88438875e051c050503fe98dcf7508dd975',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x9ea463ec4ce9e9e5bc9cfd0187c4ac3a70dd951d',
#   'contract': None,
#   'nonce': 641,
#   'changes': [],
#   'fee': {'value': 8323568000000000, 'price': 2590.67},
#   'meta': {'action': 'Approval',
#    'amount': 1.157920892373162e+77,
#    'spender': '0xb2be281e8b11b47fec825973fc8bb95332022a54',
#    'asset': {'asset_code': '0x9ea463ec4ce9e9e5bc9cfd0187c4ac3a70dd951d',
#     'name': 'ETH 20 SMA Crossover Set',
#     'symbol': 'ETH20SMACO',
#     'decimals': 18,
#     'type': 'tokenset',
#     'icon_url': 'https://token-icons.s3.amazonaws.com/0x9ea463ec4ce9e9e5bc9cfd0187c4ac3a70dd951d.png',
#     'price': {'value': 2104.69504514204,
#      'relative_change_24h': -0.8665787944034831,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': False}}},
#  {'id': '7a089989-fb83b9ee88d9ac23-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1618865006,
#   'block_number': 12272748,
#   'status': 'confirmed',
#   'hash': '0xfb83b9ee88d9ac23d741322b1247a5872581b41c3f1fb2eb1f8320a1e1d64587',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'contract': None,
#   'nonce': 640,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 520000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0xe63a87face71d7ff0794acd2263907e08fcb4a79',
#     'price': 1.0199364453}],
#   'fee': {'value': 9179660000000000, 'price': 2214.99},
#   'meta': {}},
#  {'id': '1909e8ff-de1c5a8b0c905606-7e5ce108',
#   'type': 'claim',
#   'protocol': 'curve',
#   'mined_at': 1618567213,
#   'block_number': 12250401,
#   'status': 'confirmed',
#   'hash': '0xde1c5a8b0c9056062014a98649f133f00ff934d75bab55ea98d1c1ad37316a9f',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#   'contract': None,
#   'nonce': 639,
#   'changes': [{'asset': {'asset_code': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'name': 'Curve DAO Token',
#      'symbol': 'CRV',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'price': {'value': 2.2299031781976884,
#       'relative_change_24h': 3.0080892938767922,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 768591602038813682649,
#     'direction': 'in',
#     'address_from': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 3.9807591219}],
#   'fee': {'value': 10025986500000000, 'price': 2392.01},
#   'meta': {'action': 'Claim Rewards', 'application': 'Curve'}},
#  {'id': '4ebe4846-3061e144ee55234a-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1618426721,
#   'block_number': 12239962,
#   'status': 'confirmed',
#   'hash': '0x3061e144ee55234aa5fac326fdb36d7e2a84be24b08c8c2818ca6bd65c903cd6',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#   'contract': None,
#   'nonce': 638,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 4834129148,
#     'direction': 'in',
#     'address_from': '0x004375dff511095cc5a197a54140a24efef3a416',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1.0089094656},
#    {'asset': {'asset_code': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#      'name': 'Wrapped BTC',
#      'symbol': 'WBTC',
#      'decimals': 8,
#      'type': 'bitcoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599.png',
#      'price': {'value': 35867.12570038,
#       'relative_change_24h': -3.6899232061536558,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 7800000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x004375dff511095cc5a197a54140a24efef3a416',
#     'price': 62099.42387376}],
#   'fee': {'value': 14712768000000000, 'price': 2340.64},
#   'meta': {}},
#  {'id': '088347fe-12dcd995311d6ff4-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1618426587,
#   'block_number': 12239946,
#   'status': 'confirmed',
#   'hash': '0x12dcd995311d6ff49a3e98fd6c03eccc1a1611f105c739fe8b83cffc18d15177',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'contract': None,
#   'nonce': 637,
#   'changes': [],
#   'fee': {'value': 6337520000000000, 'price': 2349.27},
#   'meta': {'action': 'Approval',
#    'amount': 1.157920892373162e+77,
#    'spender': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#    'asset': {'asset_code': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#     'name': 'Wrapped BTC',
#     'symbol': 'WBTC',
#     'decimals': 8,
#     'type': 'bitcoin',
#     'icon_url': 'https://token-icons.s3.amazonaws.com/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599.png',
#     'price': {'value': 35867.12570038,
#      'relative_change_24h': -3.6899232061536558,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': True}}},
#  {'id': 'cefa5220-ba8a9c323fbf8c63-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1618426371,
#   'block_number': 12239936,
#   'status': 'confirmed',
#   'hash': '0xba8a9c323fbf8c63464697e26e31378fa475004cf717fb2989a5eb666430fedf',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#   'contract': None,
#   'nonce': 636,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 2000000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#     'price': 2349.85},
#    {'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 4670539981,
#     'direction': 'in',
#     'address_from': '0x397ff1542f962076d0bfe58ea045ffa2d347aca0',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1.012879344}],
#   'fee': {'value': 16061080000000000, 'price': 2349.85},
#   'meta': {}},
#  {'id': '3d71c427-d62f4058e8aa39a2-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1618406359,
#   'block_number': 12238438,
#   'status': 'confirmed',
#   'hash': '0xd62f4058e8aa39a2173a454e9a3fecdaabe6dc98badda0b71c2ffa87cfbc8d8d',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'contract': None,
#   'nonce': 635,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 520000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x4e8863bc230c4c552056ede15f6533cf4fc3af35',
#     'price': 1.003855146}],
#   'fee': {'value': 7457970000000000, 'price': 2391.27},
#   'meta': {}},
#  {'id': 'df4755eb-a35f1fa5b00d023c-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1617652607,
#   'block_number': 12181671,
#   'status': 'confirmed',
#   'hash': '0xa35f1fa5b00d023c148c6f9b79ccbd59d93b8d14358ad9f74132fb842e18a882',
#   'direction': None,
#   'address_from': '0x505e20c0fb8252ca7ac21d54d5432eccd4f2d076',
#   'address_to': '0xaf7eaf66b5f1fa23158784fb4c17dba90727afad',
#   'contract': None,
#   'nonce': 925,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 666000000,
#     'direction': 'in',
#     'address_from': '0xaf7eaf66b5f1fa23158784fb4c17dba90727afad',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 0.9934473124}],
#   'fee': None,
#   'meta': {}},
#  {'id': 'cd465f05-6cee2178ccc0f564-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1617634397,
#   'block_number': 12180299,
#   'status': 'confirmed',
#   'hash': '0x6cee2178ccc0f5643ec7919c0650a0b107439949d3e34782604a9f232a613fe9',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x4976fb03c32e5b8cfe2b6ccb31c09ba78ebaba41',
#   'contract': None,
#   'nonce': 634,
#   'changes': [],
#   'fee': {'value': 11853224000000000, 'price': 2121.21},
#   'meta': {}},
#  {'id': '090adb35-d9d99e8980c4f80d-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1616200968,
#   'block_number': 12072505,
#   'status': 'confirmed',
#   'hash': '0xd9d99e8980c4f80d627cb653977ca007ad3fc7af9a225b5e460b85a2d1cfcbd9',
#   'direction': None,
#   'address_from': '0x523d643e3d7c455d043ee11b51bc8ec08f6ff474',
#   'address_to': '0x660f6d6c9bcd08b86b50e8e53b537f2b40f243bd',
#   'contract': None,
#   'nonce': 66,
#   'changes': [{'asset': {'asset_code': '0x35bd01fc9d6d5d81ca9e055db88dc49aa2c699a8',
#      'name': 'Friends With Benefits Pro',
#      'symbol': 'FWB',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x35bd01fc9d6d5d81ca9e055db88dc49aa2c699a8.png',
#      'price': {'value': 5.5690709836983405,
#       'relative_change_24h': -1.7873746411183555,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 100000000000000000000,
#     'direction': 'in',
#     'address_from': '0x660f6d6c9bcd08b86b50e8e53b537f2b40f243bd',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 39.6423777575}],
#   'fee': None,
#   'meta': {}},
#  {'id': 'c345b51c-a3c4890f388012e7-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1616065350,
#   'block_number': 12062251,
#   'status': 'confirmed',
#   'hash': '0xa3c4890f388012e7dfa0b96adef96da165a6d56a8a726be6b9eb1901ee277f4a',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 633,
#   'changes': [{'asset': {'asset_code': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'name': 'Curve DAO Token',
#      'symbol': 'CRV',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'price': {'value': 2.2299031781976884,
#       'relative_change_24h': 3.0080892938767922,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 140170369447133721084,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x3da1313ae46132a397d90d95b1424a9a7e3e0fce',
#     'price': 2.5485866273},
#    {'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 194744220125392241,
#     'direction': 'in',
#     'address_from': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1824.89}],
#   'fee': {'value': 15690574000000000, 'price': 1824.89},
#   'meta': {}},
#  {'id': '9dea8752-817ce56456319cad-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1613998223,
#   'block_number': 11906931,
#   'status': 'failed',
#   'hash': '0x817ce56456319cad42544b68cab15ee93a4f90c6ee805038e3491ecbaf83a521',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 632,
#   'changes': [],
#   'fee': {'value': 5357782000000000, 'price': 1792.64},
#   'meta': {}},
#  {'id': 'e7bd355a-5e9336ab0e7ef678-7e5ce108',
#   'type': 'claim',
#   'protocol': 'curve',
#   'mined_at': 1613995177,
#   'block_number': 11906682,
#   'status': 'confirmed',
#   'hash': '0x5e9336ab0e7ef6784ee5202c48237897ad6d268e106365236eaf83731cba3930',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#   'contract': None,
#   'nonce': 631,
#   'changes': [{'asset': {'asset_code': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'name': 'Curve DAO Token',
#      'symbol': 'CRV',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'price': {'value': 2.2299031781976884,
#       'relative_change_24h': 3.0080892938767922,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 140170369447133721084,
#     'direction': 'in',
#     'address_from': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 2.6930674632}],
#   'fee': {'value': 10659470000000000, 'price': 1817.16},
#   'meta': {'action': 'Claim Rewards', 'application': 'Curve'}},
#  {'id': '13800b95-cb1d494ab366fbb7-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1613994929,
#   'block_number': 11906663,
#   'status': 'confirmed',
#   'hash': '0xcb1d494ab366fbb71aae2932b31b38278801165299b2e7191305df59fb48e12e',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 630,
#   'changes': [{'asset': {'asset_code': '0x43dfc4159d86f3a37a5a4b3d4580b888ad7d4ddd',
#      'name': 'DODO bird',
#      'symbol': 'DODO',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xd5f1c30971d20f4553680f252d140c2093ab41cc.png',
#      'price': {'value': 1.2778953759,
#       'relative_change_24h': -6.915559172259367,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 410874749145379199376,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x68fa181c720c07b7ff7412220e2431ce90a65a14',
#     'price': 6.127663267},
#    {'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1365776172030037273,
#     'direction': 'in',
#     'address_from': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1824.35}],
#   'fee': {'value': 16713432250226272, 'price': 1824.35},
#   'meta': {}},
#  {'id': '7f9d08ce-48aa5eaa40bf6706-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1613994860,
#   'block_number': 11906655,
#   'status': 'confirmed',
#   'hash': '0x48aa5eaa40bf6706a8d8a6e3bbd6af137dac65d267f043870aeacc232a67f361',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x43dfc4159d86f3a37a5a4b3d4580b888ad7d4ddd',
#   'contract': None,
#   'nonce': 629,
#   'changes': [],
#   'fee': {'value': 7505459000000000, 'price': 1824.35},
#   'meta': {'action': 'Approval',
#    'amount': 1.157920892373162e+77,
#    'spender': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'asset': {'asset_code': '0x43dfc4159d86f3a37a5a4b3d4580b888ad7d4ddd',
#     'name': 'DODO bird',
#     'symbol': 'DODO',
#     'decimals': 18,
#     'type': None,
#     'icon_url': 'https://token-icons.s3.amazonaws.com/0xd5f1c30971d20f4553680f252d140c2093ab41cc.png',
#     'price': {'value': 1.2778953759,
#      'relative_change_24h': -6.915559172259367,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': True}}},
#  {'id': '29fdd88e-05e901861ea474a3-7e5ce108',
#   'type': 'claim',
#   'protocol': 'dodo',
#   'mined_at': 1613994811,
#   'block_number': 11906650,
#   'status': 'confirmed',
#   'hash': '0x05e901861ea474a3eb73ca05daf8357cae716135abc340478bf8951b0654d301',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xaed7384f03844af886b830862ff0a7afce0a632c',
#   'contract': None,
#   'nonce': 628,
#   'changes': [{'asset': {'asset_code': '0x43dfc4159d86f3a37a5a4b3d4580b888ad7d4ddd',
#      'name': 'DODO bird',
#      'symbol': 'DODO',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xd5f1c30971d20f4553680f252d140c2093ab41cc.png',
#      'price': {'value': 1.2778953759,
#       'relative_change_24h': -6.915559172259367,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 188886406718767518255,
#     'direction': 'in',
#     'address_from': '0x380312700ed61e4401d27e62508b82d0ae162d9e',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 6.127663267}],
#   'fee': {'value': 21863006000000000, 'price': 1824.35},
#   'meta': {'action': 'Claim Rewards', 'application': 'Dodo'}},
#  {'id': '35899497-08e49503d06f9b9b-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1613994757,
#   'block_number': 11906647,
#   'status': 'confirmed',
#   'hash': '0x08e49503d06f9b9bb3c3e807ad350316e2a02b4dfc669b4a7c030358b7dc627e',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x0e504d3e053885a82bd1cb5c29cbaae5b3673be4',
#   'contract': None,
#   'nonce': 627,
#   'changes': [{'asset': {'asset_code': '0x43dfc4159d86f3a37a5a4b3d4580b888ad7d4ddd',
#      'name': 'DODO bird',
#      'symbol': 'DODO',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xd5f1c30971d20f4553680f252d140c2093ab41cc.png',
#      'price': {'value': 1.2778953759,
#       'relative_change_24h': -6.915559172259367,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 208156026340744526111,
#     'direction': 'in',
#     'address_from': '0x0e504d3e053885a82bd1cb5c29cbaae5b3673be4',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 6.1469093056}],
#   'fee': {'value': 10014641971794972, 'price': 1830.08},
#   'meta': {}},
#  {'id': 'eceb2b10-40b41f8333753d6a-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1613161587,
#   'block_number': 11844004,
#   'status': 'confirmed',
#   'hash': '0x40b41f8333753d6a7a8c37b765671d6bd9ce58d7a01870fa1044d2fcd7e08696',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 626,
#   'changes': [{'asset': {'asset_code': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'name': 'Curve DAO Token',
#      'symbol': 'CRV',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'price': {'value': 2.2299031781976884,
#       'relative_change_24h': 3.0080892938767922,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 268647042600226468174,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x3da1313ae46132a397d90d95b1424a9a7e3e0fce',
#     'price': 3.425848671},
#    {'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 493265443744973323,
#     'direction': 'in',
#     'address_from': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1851.71}],
#   'fee': {'value': 19778963000000000, 'price': 1851.71},
#   'meta': {}},
#  {'id': '09de73aa-6afebadaf465a9b7-7e5ce108',
#   'type': 'claim',
#   'protocol': 'curve',
#   'mined_at': 1613161361,
#   'block_number': 11843987,
#   'status': 'confirmed',
#   'hash': '0x6afebadaf465a9b726e0ad2d0e6ab8adfd286dd3e1944a98f5fe80c1e698c95d',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#   'contract': None,
#   'nonce': 625,
#   'changes': [{'asset': {'asset_code': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'name': 'Curve DAO Token',
#      'symbol': 'CRV',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'price': {'value': 2.2299031781976884,
#       'relative_change_24h': 3.0080892938767922,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 268647042600226468174,
#     'direction': 'in',
#     'address_from': '0x575ccd8e2d300e2377b43478339e364000318e2c',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 3.412786965}],
#   'fee': {'value': 9795918000000000, 'price': 1844.65},
#   'meta': {'action': 'Claim Rewards', 'application': 'Curve'}},
#  {'id': '74c84885-ca42ed1af5c46073-7e5ce108',
#   'type': 'trade',
#   'protocol': 'ens',
#   'mined_at': 1612519588,
#   'block_number': 11795600,
#   'status': 'confirmed',
#   'hash': '0xca42ed1af5c460731085763adb305a598500f6d906cee715499873cf36a8a438',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x283af0b28c62c092c9727f1ee09c02ca627eb7f5',
#   'contract': None,
#   'nonce': 624,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 109035940491348748,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x283af0b28c62c092c9727f1ee09c02ca627eb7f5',
#     'price': 1652.48}],
#   'fee': {'value': 16321352000000000, 'price': 1652.48},
#   'meta': {'action': 'Renew ENS Domain',
#    'duration': 1136050272,
#    'name': 'evgeny.eth',
#    'application': 'ENS'}},
#  {'id': '0c10b5ee-5dc8e7569d8fce78-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1612514355,
#   'block_number': 11795248,
#   'status': 'confirmed',
#   'hash': '0x5dc8e7569d8fce787f46568cd5d6b76b58da97e652c76dcdbb8400dd48a11032',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x4976fb03c32e5b8cfe2b6ccb31c09ba78ebaba41',
#   'contract': None,
#   'nonce': 622,
#   'changes': [],
#   'fee': {'value': 18072611000000000, 'price': 1650.44},
#   'meta': {}},
#  {'id': '0c10b5ee-17c9b89248118a9f-7e5ce108',
#   'type': 'execution',
#   'protocol': None,
#   'mined_at': 1612514355,
#   'block_number': 11795248,
#   'status': 'confirmed',
#   'hash': '0x17c9b89248118a9fc0c154c32ba627f76e4fd4f34b0c59ee0c047b3ff34f5730',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x00000000000c2e074ec69a0dfb2997ba6c7d2e1e',
#   'contract': None,
#   'nonce': 623,
#   'changes': [],
#   'fee': {'value': 5869636507863040, 'price': 1650.44},
#   'meta': {}},
#  {'id': '12524fb0-25fa20923894069b-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1612307982,
#   'block_number': 11779724,
#   'status': 'confirmed',
#   'hash': '0x25fa20923894069ba12cfb58178fbedf8c285e2471b0c47a7d28b84208b3982e',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 621,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 3203385897,
#     'direction': 'in',
#     'address_from': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1.0006945404},
#    {'asset': {'asset_code': '0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b',
#      'name': 'DefiPulse Index',
#      'symbol': 'DPI',
#      'decimals': 18,
#      'type': 'tokenset-v2',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b.png',
#      'price': {'value': 301.8025971825651,
#       'relative_change_24h': -5.53004917164931,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 10000000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x4d5ef58aac27d99935e5b6b4a6778ff292059991',
#     'price': 321.3819159375}],
#   'fee': {'value': 24251328000000000, 'price': 1525.17},
#   'meta': {}},
#  {'id': 'aa8f6373-67a3fb4d21a3a220-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1612307837,
#   'block_number': 11779710,
#   'status': 'confirmed',
#   'hash': '0x67a3fb4d21a3a2203f85e8cf602002fe82ead426ef45c57d0592e9b5feab27f6',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 620,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 1024083074,
#     'direction': 'in',
#     'address_from': '0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1.0022167388},
#    {'asset': {'asset_code': '0x0391d2021f89dc339f60fff84546ea23e337750f',
#      'name': 'BarnBridge Governance Token',
#      'symbol': 'BOND',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x0391d2021f89dc339f60fff84546ea23e337750f.png',
#      'price': {'value': 32.0656152089,
#       'relative_change_24h': -3.7519337992898194,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 18062058126894904729,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244',
#     'price': 56.3402924827}],
#   'fee': {'value': 15842691000000000, 'price': 1527.49},
#   'meta': {}},
#  {'id': '68ae0dce-72522ab13e48898f-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1612307806,
#   'block_number': 11779706,
#   'status': 'confirmed',
#   'hash': '0x72522ab13e48898f353c2a080c4ebe1536fdc1e6d417e1e249614fee69a8d359',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x0391d2021f89dc339f60fff84546ea23e337750f',
#   'contract': None,
#   'nonce': 619,
#   'changes': [],
#   'fee': {'value': 6794118000000000, 'price': 1527.49},
#   'meta': {'action': 'Approval',
#    'amount': 1.157920892373162e+77,
#    'spender': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#    'asset': {'asset_code': '0x0391d2021f89dc339f60fff84546ea23e337750f',
#     'name': 'BarnBridge Governance Token',
#     'symbol': 'BOND',
#     'decimals': 18,
#     'type': None,
#     'icon_url': 'https://token-icons.s3.amazonaws.com/0x0391d2021f89dc339f60fff84546ea23e337750f.png',
#     'price': {'value': 32.0656152089,
#      'relative_change_24h': -3.7519337992898194,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': True}}},
#  {'id': 'bae28995-3e42de0867fc7689-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1612307377,
#   'block_number': 11779677,
#   'status': 'confirmed',
#   'hash': '0x3e42de0867fc76892fd277aaa11259a8c04c38cb2ec616b5ec94e8b2c87aca60',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f',
#   'contract': None,
#   'nonce': 618,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 2016444904,
#     'direction': 'in',
#     'address_from': '0x397ff1542f962076d0bfe58ea045ffa2d347aca0',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 1.0058253988},
#    {'asset': {'asset_code': '0x0954906da0bf32d5479e25f46056d22f08464cab',
#      'name': 'Index',
#      'symbol': 'INDEX',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x0954906da0bf32d5479e25f46056d22f08464cab.png',
#      'price': {'value': 22.579218165371245,
#       'relative_change_24h': -3.3629128780409023,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 57968793215906540634,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0xa73df646512c82550c2b3c0324c4eedee53b400c',
#     'price': 34.5095058076}],
#   'fee': {'value': 26546292000000000, 'price': 1532.99},
#   'meta': {}},
#  {'id': 'e6d8d19a-49aa5b1ecb793362-7e5ce108',
#   'type': 'authorize',
#   'protocol': None,
#   'mined_at': 1612307309,
#   'block_number': 11779675,
#   'status': 'confirmed',
#   'hash': '0x49aa5b1ecb7933626eee79dcea36b14fc1a451ce9c61dfe3cde281a3d185fe55',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x0954906da0bf32d5479e25f46056d22f08464cab',
#   'contract': None,
#   'nonce': 617,
#   'changes': [],
#   'fee': {'value': 7348644000000000, 'price': 1532.9},
#   'meta': {'action': 'Approval',
#    'amount': 1.157920892373162e+77,
#    'spender': '0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f',
#    'asset': {'asset_code': '0x0954906da0bf32d5479e25f46056d22f08464cab',
#     'name': 'Index',
#     'symbol': 'INDEX',
#     'decimals': 18,
#     'type': None,
#     'icon_url': 'https://token-icons.s3.amazonaws.com/0x0954906da0bf32d5479e25f46056d22f08464cab.png',
#     'price': {'value': 22.579218165371245,
#      'relative_change_24h': -3.3629128780409023,
#      'changed_at': 0},
#     'is_displayable': True,
#     'is_verified': True}}},
#  {'id': '0a4fd873-d3bf22479de38287-7e5ce108',
#   'type': 'send',
#   'protocol': None,
#   'mined_at': 1612263288,
#   'block_number': 11776392,
#   'status': 'confirmed',
#   'hash': '0xd3bf22479de382872a231f921ee504cd847085376c8e0f0851db8f630c1703aa',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x5fb27fdce1d062bf6239eeaf8f971cdfca23620f',
#   'contract': None,
#   'nonce': 616,
#   'changes': [{'asset': {'asset_code': 'eth',
#      'name': 'Ethereum',
#      'symbol': 'ETH',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://s3.amazonaws.com/token-icons/eth.png',
#      'price': {'value': 2421.77,
#       'relative_change_24h': -0.866578794403472,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 100000000000000000,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x5fb27fdce1d062bf6239eeaf8f971cdfca23620f',
#     'price': 1435.86}],
#   'fee': {'value': 2148300033684000, 'price': 1435.86},
#   'meta': {}},
#  {'id': '4dd1005b-9b69fa2c764c59cf-7e5ce108',
#   'type': 'receive',
#   'protocol': None,
#   'mined_at': 1612106244,
#   'block_number': 11764565,
#   'status': 'confirmed',
#   'hash': '0x9b69fa2c764c59cf276e8d8ede6cdc618993cf5e6b9891f66b3322f27243bad3',
#   'direction': None,
#   'address_from': '0xba9fec0023e6aa54d96617cdb3e5507ff20f8b81',
#   'address_to': '0x7d91e637589ec3bb54d8213a9e92dc6e8d12da91',
#   'contract': None,
#   'nonce': 65,
#   'changes': [{'asset': {'asset_code': '0x7d91e637589ec3bb54d8213a9e92dc6e8d12da91',
#      'name': 'FRIENDS WITH BENEFITS',
#      'symbol': 'FWB',
#      'decimals': 4,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x7d91e637589ec3bb54d8213a9e92dc6e8d12da91.png',
#      'price': None,
#      'is_displayable': True,
#      'is_verified': False},
#     'value': 1000000,
#     'direction': 'in',
#     'address_from': '0xba9fec0023e6aa54d96617cdb3e5507ff20f8b81',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 10.0485068552}],
#   'fee': None,
#   'meta': {}},
#  {'id': '91a3098c-c9df780e9d690664-7e5ce108',
#   'type': 'trade',
#   'protocol': None,
#   'mined_at': 1612089655,
#   'block_number': 11763297,
#   'status': 'confirmed',
#   'hash': '0xc9df780e9d6906648884e90313dd274b0666fed39eba7aa27c7417583d349d9f',
#   'direction': 'out',
#   'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#   'address_to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#   'contract': None,
#   'nonce': 615,
#   'changes': [{'asset': {'asset_code': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'name': 'USD Coin',
#      'symbol': 'USDC',
#      'decimals': 6,
#      'type': 'stablecoin',
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'price': {'value': 1.003337810547855,
#       'relative_change_24h': -0.7253258655685157,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 2026652180,
#     'direction': 'in',
#     'address_from': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc',
#     'address_to': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'price': 0.9998887067},
#    {'asset': {'asset_code': '0x86772b1409b61c639eaac9ba0acfbb6e238e5f83',
#      'name': 'Indexed',
#      'symbol': 'NDX',
#      'decimals': 18,
#      'type': None,
#      'icon_url': 'https://token-icons.s3.amazonaws.com/0x86772b1409b61c639eaac9ba0acfbb6e238e5f83.png',
#      'price': {'value': 6.176015833011353,
#       'relative_change_24h': -9.589418599075461,
#       'changed_at': 0},
#      'is_displayable': True,
#      'is_verified': True},
#     'value': 311085144781464692478,
#     'direction': 'out',
#     'address_from': '0x7e5ce10826ee167de897d262fcc9976f609ecd2b',
#     'address_to': '0x46af8ac1b82f73db6aacc1645d40c56191ab787b',
#     'price': 6.4800130772}],
#   'fee': {'value': 12816012000000000, 'price': 1343.81},
#   'meta': {}}]

# %%
test_address = '0x7e5ce10826ee167de897d262fcc9976f609ecd2b'

f = FactoryClient(setting_path='../settings.yaml')
result = f.sync_request(
    namespace='/address',
    payload={
        'address': test_address,
        'charts_type': 'y'
    },
    scope='charts'
)
# Out:
# Connected to /address namespace!
# Address portfolio is received

# %%
chart = pd.DataFrame(result['others'])

# %%
chart[0] = chart[0].apply(lambda x: datetime.datetime.fromtimestamp(x))

# %%
px.scatter(chart, x=0, y=1)
# Out:
# <div>                            <div id="98aa2ac8-1c5d-4b0a-b52d-c98f3112f4cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98aa2ac8-1c5d-4b0a-b52d-c98f3112f4cb")) {                    Plotly.newPlot(                        "98aa2ac8-1c5d-4b0a-b52d-c98f3112f4cb",                        [{"hovertemplate": "0=%{x}<br>1=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2021-06-13T03:00:00", "2021-06-12T03:00:00", "2021-06-11T03:00:00", "2021-06-10T03:00:00", "2021-06-09T03:00:00", "2021-06-08T03:00:00", "2021-06-07T03:00:00", "2021-06-06T03:00:00", "2021-06-05T03:00:00", "2021-06-04T03:00:00", "2021-06-03T03:00:00", "2021-06-02T03:00:00", "2021-06-01T03:00:00", "2021-05-31T03:00:00", "2021-05-30T03:00:00", "2021-05-29T03:00:00", "2021-05-28T03:00:00", "2021-05-27T03:00:00", "2021-05-26T03:00:00", "2021-05-25T03:00:00", "2021-05-24T03:00:00", "2021-05-23T03:00:00", "2021-05-22T03:00:00", "2021-05-21T03:00:00", "2021-05-20T03:00:00", "2021-05-19T03:00:00", "2021-05-18T03:00:00", "2021-05-17T03:00:00", "2021-05-16T03:00:00", "2021-05-15T03:00:00", "2021-05-14T03:00:00", "2021-05-13T03:00:00", "2021-05-12T03:00:00", "2021-05-11T03:00:00", "2021-05-10T03:00:00", "2021-05-09T03:00:00", "2021-05-08T03:00:00", "2021-05-07T03:00:00", "2021-05-06T03:00:00", "2021-05-05T03:00:00", "2021-05-04T03:00:00", "2021-05-03T03:00:00", "2021-05-02T03:00:00", "2021-05-01T03:00:00", "2021-04-30T03:00:00", "2021-04-29T03:00:00", "2021-04-28T03:00:00", "2021-04-27T03:00:00", "2021-04-26T03:00:00", "2021-04-25T03:00:00", "2021-04-24T03:00:00", "2021-04-23T03:00:00", "2021-04-22T03:00:00", "2021-04-21T03:00:00", "2021-04-20T03:00:00", "2021-04-19T03:00:00", "2021-04-18T03:00:00", "2021-04-17T03:00:00", "2021-04-16T03:00:00", "2021-04-15T03:00:00", "2021-04-14T03:00:00", "2021-04-13T03:00:00", "2021-04-12T03:00:00", "2021-04-11T03:00:00", "2021-04-10T03:00:00", "2021-04-09T03:00:00", "2021-04-08T03:00:00", "2021-04-07T03:00:00", "2021-04-06T03:00:00", "2021-04-05T03:00:00", "2021-04-04T03:00:00", "2021-04-03T03:00:00", "2021-04-02T03:00:00", "2021-04-01T03:00:00", "2021-03-31T03:00:00", "2021-03-30T03:00:00", "2021-03-29T03:00:00", "2021-03-28T03:00:00", "2021-03-27T03:00:00", "2021-03-26T03:00:00", "2021-03-25T03:00:00", "2021-03-24T03:00:00", "2021-03-23T03:00:00", "2021-03-22T03:00:00", "2021-03-21T03:00:00", "2021-03-20T03:00:00", "2021-03-19T03:00:00", "2021-03-18T03:00:00", "2021-03-17T03:00:00", "2021-03-16T03:00:00", "2021-03-15T03:00:00", "2021-03-14T03:00:00", "2021-03-13T03:00:00", "2021-03-12T03:00:00", "2021-03-11T03:00:00", "2021-03-10T03:00:00", "2021-03-09T03:00:00", "2021-03-08T03:00:00", "2021-03-07T03:00:00", "2021-03-06T03:00:00", "2021-03-05T03:00:00", "2021-03-04T03:00:00", "2021-03-03T03:00:00", "2021-03-02T03:00:00", "2021-03-01T03:00:00", "2021-02-28T03:00:00", "2021-02-27T03:00:00", "2021-02-26T03:00:00", "2021-02-25T03:00:00", "2021-02-24T03:00:00", "2021-02-23T03:00:00", "2021-02-22T03:00:00", "2021-02-21T03:00:00", "2021-02-20T03:00:00", "2021-02-19T03:00:00", "2021-02-18T03:00:00", "2021-02-17T03:00:00", "2021-02-16T03:00:00", "2021-02-15T03:00:00", "2021-02-14T03:00:00", "2021-02-13T03:00:00", "2021-02-12T03:00:00", "2021-02-11T03:00:00", "2021-02-10T03:00:00", "2021-02-09T03:00:00", "2021-02-08T03:00:00", "2021-02-07T03:00:00", "2021-02-06T03:00:00", "2021-02-05T03:00:00", "2021-02-04T03:00:00", "2021-02-03T03:00:00", "2021-02-02T03:00:00", "2021-02-01T03:00:00", "2021-01-31T03:00:00", "2021-01-30T03:00:00", "2021-01-29T03:00:00", "2021-01-28T03:00:00", "2021-01-27T03:00:00", "2021-01-26T03:00:00", "2021-01-25T03:00:00", "2021-01-24T03:00:00", "2021 ...

# %%
from defisdk import DeFiSDK

# %%
defi_sdk = DeFiSDK('https://mainnet.infura.io/v3/91d1551e285748ea8acf1fbf9a31f26e')

# %%
await defi_sdk.get_protocol_names()
# Out:
# ['Liquity',
#  'bZx • Vested Staking',
#  'bZx • Staking',
#  'Alpha Homora V2',
#  'Stake DAO',
#  'Saddle',
#  'Reflexer',
#  'Curve • Vote Escrowed CRV',
#  'Cometh • Tube',
#  'Cometh • Staking',
#  '1inch LP • Staking',
#  'Livepeer',
#  'Alpha Homora',
#  'mStable V2',
#  'Enzyme',
#  'Yearn Token Vaults',
#  'PoolTogether V3',
#  '1inch Liquidity Protocol',
#  'SushiSwap • Staking',
#  'Mushrooms Finance',
#  'Mushrooms Finance • Staking',
#  'Akropolis • AKRO Staking',
#  'Akropolis • ADEL Staking',
#  'Bancor • Locked BNT',
#  'Bancor • Liquidity Protection',
#  'PieDAO ExperiPies',
#  'SnowSwap',
#  'Aave V2 • Variable Debt',
#  'Aave V2 • Stable Debt',
#  'Aave V2',
#  'Idle • Early Rewards',
#  'Harvest • Profit Sharing',
#  'Curve • Vesting',
#  'Curve • Liquidity Gauges',
#  'ygov.finance (v1)',
#  'ygov.finance (v2)',
#  'mStable • Staking',
#  'Swerve • Liquidity Gauges',
#  'Pickle Finance • Farms',
#  'Pickle Finance • Staking',
#  'Aave • Staking',
#  'C.R.E.A.M. • Staking',
#  'Compound Governance',
#  'zlot.finance',
#  'FinNexus',
#  'Pickle Finance',
#  'DODO',
#  'Berezka',
#  'bZx',
#  'C.R.E.A.M.',
#  'Swerve',
#  'SashimiSwap',
#  'Harvest',
#  'KIMCHI',
#  'SushiSwap',
#  'Nexus Mutual',
#  'Mooniswap',
#  'Matic',
#  'Aragon',
#  'Melon',
#  'yearn.finance • Vaults',
#  'KeeperDAO',
#  'mStable',
#  'KyberDAO',
#  'DDEX • Spot',
#  'DDEX • Margin',
#  'DDEX • Lending',
#  'Ampleforth',
#  'Maker Governance',
#  'Gnosis Protocol',
#  'Chi Gastoken by 1inch',
#  'Idle • Risk-Adjusted',
#  'Aave • Uniswap Market',
#  'Uniswap V2',
#  'PieDAO',
#  'Multi-Collateral Dai',
#  'Bancor',
#  'DeFi Money Market',
#  'TokenSets',
#  '0x Staking',
#  'Uniswap V1',
#  'Synthetix',
#  'PoolTogether',
#  'Dai Savings Rate',
#  'Chai',
#  'iearn.finance (v3)',
#  'iearn.finance (v2)',
#  'Idle',
#  'dYdX',
#  'Curve',
#  'Compound',
#  'Balancer',
#  'Aave']
