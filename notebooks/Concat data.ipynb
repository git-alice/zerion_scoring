# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sys import path
path.append('../')

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import datetime
import plotly.express as px
from pathlib import Path
import time

# %%
def get_top_address():
    return list(Path('../data/part1/').glob('*'))

def get_bottom_address():
    return list(Path('../data/part2/').glob('*'))

# %%
full_df = pd.DataFrame()

for address in get_top_address():
    chunk = pd.read_hdf(address)
    chunk.index.name = 'transaction'
    chunk['address'] = address.stem
    chunk = chunk.reset_index().set_index(['address', 'transaction'])
    chunk['address_type'] = 'top100'
    full_df = pd.concat([chunk, full_df])
    
for address in get_bottom_address():
    chunk = pd.read_hdf(address)
    chunk.index.name = 'transaction'
    chunk['address'] = address.stem
    chunk = chunk.reset_index().set_index(['address', 'transaction'])
    chunk['address_type'] = 'bottom'
    full_df = pd.concat([chunk, full_df])

# %%
# for address, df in full_df.reset_index().groupby('address'):
#     fig = px.scatter(df, x='timestamp', y='balance')
#     fig.show()

# %%
full_df
# Out:
#                                                                                                 timestamp  \
# address                                    transaction
# 0x2e7b037020c642471620f2caeef77f77da904cea 0xa4d9e783676b7610e25b677edda7024d5c5e08f5f0a15...  1623555088
#                                            0x10a683c8ac2d6453ac189bc0a1c5876abb41b52c508ba...  1623554917
#                                            0xdb1fe4b3466496de4ce56f7d1a0d29992359989d85930...  1623546470
#                                            0x412212a1c6c798e310d417eeaec4bf1df38e548cf59b7...  1623495606
#                                            0x689240f9ab0a8ce15c95f671ae20cbdc479ac321ae7a2...  1623495405
# ...                                                                                                   ...
# 0x42abc9fc7aac448acfa8a4899ccaff50a366df73 0x81e61fd41f8ca6eb0e00212cd8ec9f21c5505ba764aa7...  1600648364
# ...
